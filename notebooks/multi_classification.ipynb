# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import os
os.chdir("..") 
from scripts.train_and_test import *
data_path = r"C:\Users\chloe\OneDrive\Desktop\materials classification\features_dataset_plus.csv"

X_train_scaled, X_test_scaled, y_train, y_test, n_features, label_encoders, scaler = load_multilabel_data(data_path)

results = train_multilabel_classifiers(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Data shape: (6981, 85)
# Number of labels: 2
#   material: ['Al' 'Cu' 'FEP' 'PE' 'PET' 'PI' 'Paper']
#   location: ['bottom' 'center' 'left' 'right' 'top']
#
# Train set: 5584 samples
# Test set: 1397 samples
#
# Multilabel SVM
#   Overall Accuracy: 0.6001 (+/- 0.0124)
#   material Accuracy: 0.7837
#   location Accuracy: 0.7333
#
# Multilabel KNN
#   Overall Accuracy: 0.8515 (+/- 0.0118)
#   material Accuracy: 0.9173
#   location Accuracy: 0.8858
#
# Multilabel Random Forest
#   Overall Accuracy: 0.9825 (+/- 0.0053)
#   material Accuracy: 0.9878
#   location Accuracy: 0.9901
#
# Multilabel Decision Tree
#   Overall Accuracy: 0.8920 (+/- 0.0074)
#   material Accuracy: 0.9418
#   location Accuracy: 0.9400
